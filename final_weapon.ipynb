# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import os
HOME=os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/FINAL_GS_weapon2

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.2/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/FINAL_GS_weapon2
# Out:
# /content/drive/MyDrive/FINAL_GS_weapon2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=224 plots=True
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
Image(filename='/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/results.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/P_curve.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/R_curve.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/PR_curve.png', width=600)

# %%
Image(filename="/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/confusion_matrix.png" , width=600)

# %%
# !ls runs/detect/train2/
# Out:
# args.yaml					    P_curve.png       train_batch2.jpg
# confusion_matrix_normalized.png			    PR_curve.png      train_batch420.jpg
# confusion_matrix.png				    R_curve.png       train_batch421.jpg
# events.out.tfevents.1702648999.75cd95999981.6856.0  results.csv       train_batch422.jpg
# F1_curve.png					    results.png       val_batch0_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg  val_batch0_pred.jpg
# labels.jpg					    train_batch1.jpg  weights

# %%
Image(filename='/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/train_batch0.jpg', width=600)

# %%
Image(filename='/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train3/train_batch1.jpg', width=600)

# %%
Image(filename='/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/train_batch420.jpg', width=600)

# %%
Image(filename='/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/train_batch422.jpg', width=600)

# %%
Image(filename='/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train3/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/FINAL_GS_weapon2/weapon_data/labels/val.cache... 30 images, 0 backgrounds, 0 corrupt: 100% 30/30 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:07<00:00,  3.67s/it]
#                    all         30         47      0.742       0.49      0.576      0.284
# Speed: 2.5ms preprocess, 223.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/weights/best.pt conf=0.25 source=/content/drive/MyDrive/FINAL_GS_weapon2/weapon_data/images/test/116_jpeg.rf.182ed1b5b3e12352ac39e03db712d5f5.jpg
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/FINAL_GS_weapon2/weapon_data/images/test/116_jpeg.rf.182ed1b5b3e12352ac39e03db712d5f5.jpg: 224x224 1 weapon, 104.1ms
# Speed: 1.0ms preprocess, 104.1ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
model = YOLO('/content/drive/MyDrive/FINAL_GS_weapon2/runs/detect/train2/weights/best.pt')

# %%
model.predict("/content/drive/MyDrive/FINAL_GS_weapon2/weapon_data/images/test/116_jpeg.rf.182ed1b5b3e12352ac39e03db712d5f5.jpg" , save = True , save_txt = True)
# Out:
# image 1/1 /content/drive/MyDrive/FINAL_GS_weapon2/weapon_data/images/test/116_jpeg.rf.182ed1b5b3e12352ac39e03db712d5f5.jpg: 224x224 1 weapon, 163.1ms
# Speed: 1.5ms preprocess, 163.1ms inference, 6.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict2
# 1 label saved to runs/detect/predict2/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'weapon'}
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
# ...
